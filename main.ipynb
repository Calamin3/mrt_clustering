# %% [markdown]
# # MRT OD Matrix in Singapore
#
# > Assignment on clustering based on OD matrix in context of Singapore's Public Transportation System
#
#
# - toc: true
# - badges: false
# - comments: true
# - categories: [sg]
# - image: images/tel2_sm-20-03-en-exp.png

# %% [markdown]
# In Singapore, one of the main forms of public transportation is via MRT/LRT. One assignment that I have performed is to use the commuting data for MRT and employ appropriate cluster analysis methods to group these stations into homogeneous groups using the origin-destination data. We are interested to find out the weekday AM (7-9am) and PM peak (5-7pm) for the journey-to-work and journey-to-home trips, and for weekend interaction during noon times (11-1pm).

# %% [markdown]
# ## Literature
#
# Some useful literature for reading
# -   [Public Transport OD matrices](https://www.diva-portal.org/smash/get/diva2:1523822/FULLTEXT01.pdf)
# - [Identifying Functional Regions in Australia Using Hierarchical Aggregation Techniques](https://onlinelibrary.wiley.com/doi/full/10.1111/j.1745-5871.2009.00631.x)

# %% [markdown]
# ## Getting the data

# %% [markdown]
# Data can be found via the Land Transport Authority [Data Mall](https://datamall.lta.gov.sg/content/datamall/en.html) via an API call. I have also included the codes for API call but the accountkey have to be requested.

# %%
import pandas as pd
import numpy as np
import requests
import seaborn as sns
import matplotlib.pyplot as plt

from pandas_profiling import ProfileReport

# %%
# #to get files from lta datamall
# import requests
# def get_data():
#         url = 'http://datamall2.mytransport.sg/ltaodataservice/PV/ODTrain'
#         headers = {'AccountKey':'your key here','accept':'application/json'}
#         payload = {'Date':YYYYMM} 
#         return requests.get(url,params=payload,headers=headers).json()

# link = get_data()['value'][0]['Link']
# # extract csv from link for the month's data

# %%
# extract csv from link above for the month's data
df = pd.read_csv('origin_destination_train_202205.csv')
df=df.drop(['YEAR_MONTH','PT_TYPE'],axis=1)

# %% [markdown]
# ## Displaying MRT stations and lines
#
# For the purpose of visual displays, we will make use of the python package [Folium](https://python-visualization.github.io/folium/) to create a nice display of all the train stations. The coordinates of MRT stations as of now can be found pretty much anywhere, but i have used [this](https://github.com/hxchua/datadoubleconfirm) repo and added new stations manually.

# %%
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# Let's try to visualize the MRT systems maps by colour. Since folium doesn't have the color brown, I have used pink instead for the TEL line

# %%
#Define coordinates of where we want to center our map
sg = [1.3561519863229077, 103.80586415619761]

#Create the map
my_map = folium.Map(location = sg, zoom_start = 12)

#Load list of stations
mrt = pd.read_csv('mrt.csv')

def add_markers(stations,map,colour='default'):

    for stn in stations:
        stn_coor = list(mrt.loc[mrt['STN_NO']==stn,['Latitude','Longitude']].values[0])
        if colour=='default':
            stn_color = mrt.loc[mrt['STN_NO']==stn,['COLOR']].values[0][0].lower()
        else:
            stn_color = colour
        stn_full_name = mrt.loc[mrt['STN_NO']==stn,['STN_NAME']].values[0][0]

        if (ind1 := stn_full_name.find('MRT')) > -1:
            stn_name = stn_full_name[:ind1-1].title()
        elif (ind2 := stn_full_name.find('LRT')) > -1:
            stn_name = stn_full_name[:ind2-1].title()
        else:
            stn_name = stn_full_name

        if stn_color == 'gray':
            stn_color = 'lightgray'

        #print(stn_coor,stn_color,stn)
        folium.Marker(location=stn_coor, popup = stn+' '+stn_name,icon=folium.Icon(color=stn_color)).add_to(map)

stations = mrt.STN_NO.to_list()

#add markers
add_markers(stations,my_map,colour='default')

# #Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d69684abde3557ba0dc5008791d6ba6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d69684abde3557ba0dc5008791d6ba6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9d69684abde3557ba0dc5008791d6ba6 = L.map(
#                 &quot;map_9d69684abde3557ba0dc5008791d6ba6&quot;,
#                 {
#                     center: [1.3561519863229077, 103.80586415619761],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e884160e55bccb6399238322d9ca9f1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9d69684abde3557ba0dc5008791d6ba6);
#
#
#             var marker_a9b783627ffc5377922eaa43c70f2a05 = L.marker(
#                 [1.440585001, 103.8009982],
#                 {}
#             ).addTo(map_9d69684abde3557ba0dc5008791d6ba6);
#
#
#             var icon_5aa31883e29a64d62f8228feee7bf754 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a9b783627ffc5377922eaa43c70f2a05.setIcon(icon_5aa31883e29a64d62f8228feee7bf754);
#
#
#         var popup_03c4d99a80626dee48da9b6299c6d9f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af1a09df9dfa4769b7c5980bec2d224a = $(`&lt;div id=&quot;html_af1a09df9dfa4769b7c5980bec2d224a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NS10 Admiralty&lt;/div&gt;`)[0];
#                 popup_03c4d99a80626dee48da9b6299c6d9f1.setContent(html_af1a09df9dfa4769b7c5980bec2d224a);
#
#
#
#         marker_a9b783627ffc5377922eaa43c70f2a05.bindPopup(popup_03c4d99a80626dee48da9b6299c6d9f1)
#         ;
#
#
#
#
#             var marker_232d034d65e48939a3dcc0e46e751939 = L.marker(
#                 [1.316432612, 103.882893],
#                 {}
#             ).addTo(map_9d69684abde3557ba0dc5008791d6ba6);
#
#
#             var icon_c6c9242af4c6bb85a64a426fb5d00cde = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_232d034d65e48939a3dcc0e46e751939.setIcon(icon_c6c9242af4c6bb85a64a426fb5d00cde);
#
#
#         var popup_45a48002d51cbe0696fb783e761614e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b798d0f362c50b6f7c216c63fa4d48ff = $(`&lt;div id=&quot;html_b798d0f362c50b6f7c216c63fa4d48ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EW9 Aljunied&lt;/div&gt;`)[0];
#                 popup_45a48002d51cbe0696fb783e761614e7.setContent(html_b798d0f362c50b6f7c216c63fa4d48ff);
#
#
#
#         marker_232d034d65e48939a3dcc0e46e751939.bindPopup(popup_45a48002d51cbe0696fb783e761614e7)
#         ;
#
#
#
#
#             var marker_598f00d81fbaf4cef5b38ef92f7a3107 = L.marker(
#                 [1.369933175, 103.8495535],
#                 {}
#             ).addTo(map_9d69684abde3557ba0dc5008791d6ba6);
#
#
#             var icon_a56b4dc71d8415fa1450340253a006e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_598f00d81fbaf4cef5b38ef92f7a3107.setIcon(icon_a56b4dc71d8415fa1450340253a006e0);
#
#
#         var popup_8df941a9d3e9d1d5344b15c78cae6d6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46cdb4901ef2ac20945f45032f5d5f3f = $(`&lt;div id=&quot;html_46cdb4901ef2ac20945f45032f5d5f3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NS16 Ang Mo Kio&lt;/div&gt;`)[0];
#                 popup_8df941a9d3e9d1d5344b15c78cae6d6f.setContent(html_46cdb4901ef2ac20945f45032f5d5f3f);
#
#
#
#         marker_598f00d81fbaf4cef5b38ef92f7a3107.bindPopup(popup_8df941a9d3e9d1d5344b15c78cae6d6f)
#         ;
#
#
#
#
#             var marker_6f6b776b9f563b6b0b78c31cc26227cb = L.marker(
#                 [1.388092704, 103.9054179],
#                 {}
#             ).addTo(map_9d69684abde3557ba0dc5008791d6ba6);
#
#
#             var icon_49c0d1c81cfdba5a8fa3f912b616d383 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;,

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# A useful package for basic EDA is through [Pandas Profiler](https://pypi.org/project/pandas-profiling/). You may visit their project website for more details/

# %%
# file = ProfileReport(df)
# file.to_notebook_iframe()

# %% [markdown]
# Weekday number of total trips are higher than that of weekends. Mean trips for all stations are higher at 93 vs 50 for weekends. Peak OD is also highest for weekdays vs weekends

# %%
df.groupby('DAY_TYPE')['TOTAL_TRIPS'].describe()
# Out:
#                      count       mean         std  min  25%   50%   75%  \
# DAY_TYPE
# WEEKDAY           363723.0  93.888036  303.988433  1.0  4.0  15.0  59.0
# WEEKENDS/HOLIDAY  336106.0  50.504823  159.810852  1.0  3.0   9.0  32.0
#
#                       max
# DAY_TYPE
# WEEKDAY           12798.0
# WEEKENDS/HOLIDAY   5442.0

# %% [markdown]
# Let's try to find out the total trips by time for all stations for all days

# %%
df.groupby('TIME_PER_HOUR').describe()
# Out:
#               TOTAL_TRIPS                                                \
#                     count        mean         std  min  25%   50%   75%
# TIME_PER_HOUR
# 0                  3884.0    9.386972   20.068909  1.0  1.0   3.0   8.0
# 5                 19572.0   27.882485   78.796186  1.0  2.0   6.0  21.0
# 6                 32611.0   73.470087  244.369474  1.0  3.0  13.0  49.0
# 7                 37441.0  108.842739  372.845040  1.0  4.0  17.0  66.0
# 8                 38314.0   93.533669  310.211684  1.0  4.0  15.0  57.0
# 9                 37626.0   64.812018  188.997212  1.0  3.0  11.0  43.0
# 10                37812.0   58.559346  174.290314  1.0  3.0  10.0  37.0
# 11                38699.0   60.849273  187.334462  1.0  3.0  10.0  38.0
# 12                39760.0   66.604930  209.799559  1.0  3.0  11.0  42.0
# 13                39870.0   69.337848  219.528833  1.0  3.0  12.0  43.0
# 14                39623.0   65.880776  204.457741  1.0  3.0  11.0  42.0
# 15                39987.0   68.949584  211.852530  1.0  4.0  12.0  45.0
# 16                40995.0   76.218392  233.303667  1.0  4.0  14.0  50.0
# 17                42318.0  106.590434  333.401763  1.0  5.0  18.0  69.0
# 18                41708.0  120.898125  392.323923  1.0  5.0  18.0  73.0
# 19                39260.0   84.383597  269.718346  1.0  4.0  14.0  52.0
# 20                37155.0   66.658135  220.745056  1.0  3.0  11.0  40.0
# 21                35917.0   61.105020  204.300373  1.0  3.0  10.0  37.0
# 22                33151.0   43.948237  131.877848  1.0  2.0   8.0  29.0
# 23                24126.0   24.061428   67.571074  1.0  2.0   5.0  17.0
#
#
#                    max
# TIME_PER_HOUR
# 0                230.0
# 5               2067.0
# 6               7058.0
# 7              10811.0
# 8               8510.0
# 9               4904.0
# 10              4580.0
# 11              4662.0
# 12              5523.0
# 13              5585.0
# 14              5380.0
# 15              6510.0
# 16              8898.0
# 17             10503.0
# 18             12798.0
# 19              8755.0
# 20              7971.0
# 21              7423.0
# 22              3776.0
# 23              2865.0

# %% [markdown]
# Morning Peak and PM Peak have the highest mean numbers, not surprisingly. We try to separate it by weekdays and weekends to see if there is any difference

# %%
df_total_trips = df.groupby(['DAY_TYPE','TIME_PER_HOUR']).describe()['TOTAL_TRIPS'][['count','50%','mean']].rename(columns={'50%':'median'}).reset_index()
df_total_trips=df_total_trips.melt(id_vars=['DAY_TYPE','TIME_PER_HOUR'],var_name='count_type')
g = sns.catplot(data=df_total_trips,x='TIME_PER_HOUR',y='value',col='DAY_TYPE',
            row='count_type',kind='bar',row_order=['count','mean','median'],sharey=False,color='lightblue')
# for ax in g.axes:
#     ax.tick_params(labelbottom=True)
plt.show()

# %% [markdown]
# We plot the graphs of the total trips by hours for both weekday and weekends. Not surprisingly, the mean and median trips are the highest during the AM and PM peak during weekdays. For weekends, the number of trips are generally constant throughout the day, with smaller number at the beginning and end of day.

# %% [markdown]
# How about the total trips by stations? We can have 2 groups, by origin and by destination. First, by origin.

# %%
df.groupby('ORIGIN_PT_CODE')['TOTAL_TRIPS'].mean().reset_index().sort_values('TOTAL_TRIPS',ascending=False)
# Out:
#     ORIGIN_PT_CODE  TOTAL_TRIPS
# 76        EW24/NS1   259.187846
# 119      NS21/DT11   208.347993
# 72        EW2/DT32   205.494127
# 120           NS22   203.382958
# 110           NS13   199.930361
# ..             ...          ...
# 160            TE5    12.613582
# 142            PW6    12.354680
# 152            SW4    11.462328
# 138            PW1     9.931076
# 139            PW3     6.302691
#
# [164 rows x 2 columns]

# %%
plt.figure(figsize=(25,15))
g=sns.barplot(data=df.groupby('ORIGIN_PT_CODE')['TOTAL_TRIPS'].mean().sort_values(ascending=False)[:10].reset_index(),x='ORIGIN_PT_CODE',y='TOTAL_TRIPS',color='lightblue')
plt.xticks(rotation=90)
plt.title('Top 10 Mean trips by origin')
plt.show()

# %% [markdown]
# For analysis of the number of trips by origin, we can clearly see there are some areas that have higher volumes, for example the top 3 volume are at EW24/NS1 (Jurong East) at 259 trips, NS21/DT11	(Newton) at 208 trips and EW2/DT32 (Tampines) at 205 trips.

# %%
df.groupby('DESTINATION_PT_CODE')['TOTAL_TRIPS'].mean().reset_index().sort_values('TOTAL_TRIPS',ascending=False)
# Out:
#     DESTINATION_PT_CODE  TOTAL_TRIPS
# 76             EW24/NS1   261.409655
# 120                NS22   220.397902
# 130             NS9/TE2   220.258299
# 119           NS21/DT11   214.947722
# 110                NS13   210.738939
# ..                  ...          ...
# 124                NS28    12.187382
# 152                 SW4    11.871693
# 142                 PW6    11.335381
# 138                 PW1     9.417886
# 139                 PW3     7.210399
#
# [164 rows x 2 columns]

# %%
plt.figure(figsize=(25,15))
g=sns.barplot(data=df.groupby('DESTINATION_PT_CODE')['TOTAL_TRIPS'].mean().sort_values(ascending=False)[:10].reset_index(),x='DESTINATION_PT_CODE',y='TOTAL_TRIPS',color='lightblue')
plt.xticks(rotation=90)
plt.title('Mean trips by destination')
plt.show()

# %% [markdown]
# Similarly for number of trips by destination, the top 3 volume are at EW24/NS1 (Jurong East) at 261 trips, NS22 (Orchard) at 220 trips and NS9/TE2 (Woodlands) at 220 trips.

# %% [markdown]
# ## Weekday AM Peak (7-9am)

# %% [markdown]
# ### Preparing data into OD matrix
#
# - Segmentise into weekday morning peak, weekday evening peak, weekends peak
# - sum of total trips by origin and destination
# - standardisation of data (min-max scaler) with sum of sum of origin and destination

# %%
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering

# %%
#Filter to show Weekday AM Peak (7-9am)
weekday_am_peak = df[(df['DAY_TYPE']=='WEEKDAY') & (df['TIME_PER_HOUR']<=9) & (df['TIME_PER_HOUR']>=7)].drop(columns=['DAY_TYPE'])
weekday_am_peak=weekday_am_peak.groupby(['ORIGIN_PT_CODE','DESTINATION_PT_CODE']).sum().reset_index().drop(columns=['TIME_PER_HOUR'])

# %%
# To transform and find out the total_trips per pair as a pct of trips by the sum of trips from each origin station
 
weekday_am_peak.groupby('ORIGIN_PT_CODE')['TOTAL_TRIPS'].transform('sum')
weekday_am_peak['sum_total_trips_origin']=weekday_am_peak.groupby('ORIGIN_PT_CODE')['TOTAL_TRIPS'].transform('sum')
weekday_am_peak['pct_trips_sum_origin']=weekday_am_peak['TOTAL_TRIPS']/weekday_am_peak['sum_total_trips_origin']

#Creating OD matrix with origins as rows and destinations as columns, values as the normalised trips by origin
od_weekdayam_mat = weekday_am_peak.pivot(index='ORIGIN_PT_CODE',columns='DESTINATION_PT_CODE',values='pct_trips_sum_origin').fillna(0)
od_weekdayam_mat
# Out:
# DESTINATION_PT_CODE      BP10      BP11      BP12      BP13       BP2  \
# ORIGIN_PT_CODE
# BP10                 0.000000  0.019253  0.046300  0.019304  0.005552
# BP11                 0.011440  0.000000  0.010368  0.013025  0.006255
# BP12                 0.021518  0.008227  0.000000  0.008803  0.007882
# BP13                 0.039606  0.017033  0.045044  0.000000  0.018059
# BP2                  0.010395  0.004921  0.014212  0.005243  0.000000
# ...                       ...       ...       ...       ...       ...
# TE4                  0.000000  0.000000  0.000000  0.000000  0.000000
# TE5                  0.000000  0.000000  0.000098  0.000000  0.000000
# TE6                  0.000036  0.000000  0.000107  0.000071  0.000000
# TE7                  0.000000  0.000000  0.000000  0.000000  0.000000
# TE8                  0.000000  0.000000  0.000261  0.000000  0.000000
#
# DESTINATION_PT_CODE       BP3       BP4       BP5   BP6/DT1       BP7  ...  \
# ORIGIN_PT_CODE                                                         ...
# BP10                 0.008863  0.033464  0.042429  0.356390  0.022819  ...
# BP11                 0.010711  0.037875  0.031234  0.404542  0.013239  ...
# BP12                 0.011219  0.041252  0.024912  0.427881  0.008170  ...
# BP13                 0.012415  0.047917  0.011492  0.222450  0.003489  ...
# BP2                  0.007359  0.024791  0.018398  0.345690  0.004507  ...
# ...                       ...       ...       ...       ...       ...  ...
# TE4                  0.000907  0.006166  0.000000  0.000363  0.000000  ...
# TE5                  0.000295  0.007864  0.001180  0.000491  0.000295  ...
# TE6                  0.000285  0.006656  0.000356  0.002598  0.000036  ...
# TE7                  0.000267  0.003830  0.000000  0.001514  0.000000  ...
# TE8                  0.000000  0.001172  0.000000  0.001693  0.000000  ...
#
# DESTINATION_PT_CODE  SW6  SW7       SW8       TE1       TE3       TE4  \
# ORIGIN_PT_CODE
# BP10                 0.0  0.0  0.000000  0.007793  0.000306  0.001019
# BP11                 0.0  0.0  0.000000  0.014781  0.001371  0.000171
# BP12                 0.0  0.0  0.000000  0.014844  0.000288  0.000000
# BP13                 0.0  0.0  0.000000  0.016827  0.000205  0.000103
# BP2                  0.0  0.0  0.000000  0.015730  0.000184  0.000966
# ...                  ...  ...       ...       ...       ...       ...
# TE4                  0.0  0.0  0.000544  0.106456  0.054044  0.000000
# TE5                  0.0  0.0  0.000000  0.153642  0.026639  0.023690
# TE6                  0.0  0.0  0.000036  0.122762  0.018473  0.013561
# TE7                  0.0  0.0  0.000000  0.074826  0.018350  0.030376
# TE8                  0.0  0.0  0.000130  0.071382  0.020060  0.017846
#
# DESTINATION_PT_CODE       TE5       TE6       TE7       TE8
# ORIGIN_PT_CODE
# BP10                 0.000611  0.000509  0.001121  0.000102
# BP11                 0.000300  0.000000  0.000086  0.000086
# BP12                 0.000000  0.000230  0.000173  0.000058
# BP13                 0.000000  0.000000  0.000103  0.000000
# BP2                  0.000000  0.000092  0.001380  0.001058
# ...                       ...       ...       ...       ...
# TE4                  0.019405  0.052956  0.087777  0.060936
# TE5                  0.000000  0.029981  0.053868  0.036371
# TE6                  0.008578  0.000000  0.078946  0.040648
# TE7                  0.019776  0.087386  0.000000  0.042758
# TE8                  0.015110  0.065260  0.041032  0.000000
#
# [164 rows x 164 columns]

# %%
# def elbow_plot(X, clusters):
#     distortions = []
#     inertias = []
#     mapping1 = {}
#     mapping2 = {}
#     K = range(1, clusters)
#     for k in K:
    
#         kmeanModel = KMeans(n_clusters=k).fit(X)
#         kmeanModel.fit(X)
      
#         distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
#                                             'euclidean'), axis=1)) / X.shape[0])
#         inertias.append(kmeanModel.inertia_)
      
#         mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
#                                        'euclidean'), axis=1)) / X.shape[0]
#         mapping2[k] = kmeanModel.inertia_

#         print
        
#     fig, (ax1, ax2) = plt.subplots(1,2, figsize=(19,8))
#     ax1.plot(K, distortions, marker='*', label='distortion')
#     ax1.set_xlabel('Cluster')
#     ax1.set_ylabel('Distortion')
#     ax1.legend()
#     ax2.plot(K, inertias, marker='+', label='inertia')
#     ax2.set_xlabel('Cluster')
#     ax2.set_ylabel('Inertia')
#     ax2.legend()

# elbow_plot(od_weekdayam_mat, 15)

# %%
# def k_means_cluster_fit(data: pd.DataFrame,cluster_size:int): 
#     kmeans = KMeans(n_clusters=cluster_size).fit(data)
#     labels = kmeans.labels_
#     data['label'] = labels
#     # print(X[label].value_counts())
#     # print(X.groupby([label]).agg('mean'))

#     d = [','.join(data[data['label']==x].index) for x in range(cluster_size)]
#     df = pd.DataFrame(index=range(1,cluster_size+1),columns=['Stations'],data=d)

#     return df

# k_means_cluster_fit(od_weekdayam_mat,4)

# %%
# hierarchical clustering and display dendogram

def plot_dendrogram(data: pd.DataFrame, **kwargs):
    clusters = shc.linkage(data,**kwargs)
    plt.figure(figsize=(25,16))
    plt.title("Hierarchical Clustering Dendrogram")
    shc.dendrogram(Z=clusters,leaf_font_size=8,labels=data.index)
    plt.axhline(y = 0.53, color = 'r', linestyle = '-')
    plt.show()

plot_dendrogram(od_weekdayam_mat,method='ward',metric='euclidean')

# %% [markdown]
# Finding the optimal cluster size in agglomerative hierarchical clustering is to find out the largest horizontal space that doesn't have any vertical lines(space with the longest vertical lines), with the number of clusters being the vertical lines that cut the horizontal line. This meant that the separation between clusters are the largest. We can draw the horizontal line by eyeballing the y values. Here, the number of times that the horizontal line cuts through is 8.
#
# As the default euclidean distance metric with ward linkages works well, we will stick to the defaults. We also mentioned the default values here for simplicity of changing the linkage and affinity in order to tweak them later if needed.

# %%
## get df of clusters results using cluster size found

def agg_cluster_fit(data: pd.DataFrame,cluster_size: int, **kwargs):
    model = AgglomerativeClustering(n_clusters=cluster_size,**kwargs) #affinity='euclidean', linkage='ward'
    model.fit(data)

    data['label'] = model.labels_

    d = [','.join(data[data['label']==x].index) for x in range(cluster_size)]
    df = pd.DataFrame(index=range(1,cluster_size+1),columns=['Stations'],data=d)

    return df


weekday_am_peak_clusters = agg_cluster_fit(data=od_weekdayam_mat,cluster_size=8,affinity='euclidean', linkage='ward')
weekday_am_peak_clusters.style.set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_dad49_row0_col0, #T_dad49_row1_col0, #T_dad49_row2_col0, #T_dad49_row3_col0, #T_dad49_row4_col0, #T_dad49_row5_col0, #T_dad49_row6_col0, #T_dad49_row7_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_dad49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dad49_level0_col0" class="col_heading level0 col0" >Stations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dad49_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_dad49_row0_col0" class="data row0 col0" >NE1/CC29,NE10,NE11,NE12/CC13,NE13,NE14,NE15,NE16/STC,NE17/PTC,NE5,NE7/DT12,NE8,NE9,NS24/NE6/CC1,PE1,PE2,PE3,PE4,PE5,PE6,PE7,PW1,PW3,PW4,PW5,PW6,PW7,SE1,SE2,SE3,SE4,SE5,SW1,SW2,SW3,SW4,SW5,SW6,SW7,SW8</td>
#     </tr>
#     <tr>
#       <th id="T_dad49_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_dad49_row1_col0" class="data row1 col0" >CC10/DT26,CC11,CC12,CC14,CC16,CC2,CC3,CC5,CC7,CC8,CG2,DT17,DT18,EW1,EW10,EW11,EW12/DT14,EW13/NS25,EW14/NS26,EW15,EW16/NE3,EW2/DT32,EW3,EW4,EW5,EW6,EW7,EW8/CC9,EW9,NE4/DT19,NS21/DT11,NS27/CE2,NS28</td>
#     </tr>
#     <tr>
#       <th id="T_dad49_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_dad49_row2_col0" class="data row2 col0" >CC22/EW21,EW17,EW18,EW19,EW20,EW22,EW23,EW24/NS1,EW25,EW26,EW27,EW28,EW29,EW30,EW31,EW32,EW33,NS2,NS3,NS4/BP1,NS5</td>
#     </tr>
#     <tr>
#       <th id="T_dad49_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_dad49_row3_col0" class="data row3 col0" >BP10,BP11,BP12,BP13,BP2,BP3,BP4,BP5,BP7,BP8,BP9</td>
#     </tr>
#     <tr>
#       <th id="T_dad49_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_dad49_row4_col0" class="data row4 col0" >BP6/DT1,CE1/DT16,DT10,DT13,DT2,DT3,DT5,DT6,DT7,DT8</td>
#     </tr>
#     <tr>
#       <th id="T_dad49_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_dad49_row5_col0" class="data row5 col0" >CC4/DT15,CC6,CG1/DT35,DT20,DT21,DT22,DT23,DT24,DT25,DT27,DT28,DT29,DT30,DT31,DT33,DT34</td>
#     </tr>
#     <tr>
#       <th id="T_dad49_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_dad49_row6_col0" class="data row6 col0" >CC17/TE9,CC19/DT9,CC20,CC21,CC23,CC24,CC25,CC26,CC27,CC28,TE1,TE3,TE4,TE5,TE6,TE7,TE8</td>
#     </tr>
#     <tr>
#       <th id="T_dad49_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_dad49_row7_col0" class="data row7 col0" >NS10,NS11,NS12,NS13,NS14,NS15,NS16,NS17/CC15,NS18,NS19,NS20,NS22,NS23,NS7,NS8,NS9/TE2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Lets try to visualize the clusters on a map. Each cluster is set to a different colour so that we can identify the stations in a cluster easily.

# %%
# set a colour for each cluster

weekday_am_peak_clusters['cluster_colour']=['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige']

#Define coordinates of where we want to center our map
sg = [1.3561519863229077, 103.80586415619761]

#Create the map
my_map = folium.Map(location = sg, zoom_start = 12)

#add markers
for i in range(len(weekday_am_peak_clusters)):
    cluster_list = weekday_am_peak_clusters.iloc[i].to_list()[0].split(',')
    colour = weekday_am_peak_clusters.iloc[i].to_list()[1]
    add_markers(cluster_list,my_map,colour=colour)

# #Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9df4da7d51b1bd115a632619ac95f02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9df4da7d51b1bd115a632619ac95f02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e9df4da7d51b1bd115a632619ac95f02 = L.map(
#                 &quot;map_e9df4da7d51b1bd115a632619ac95f02&quot;,
#                 {
#                     center: [1.3561519863229077, 103.80586415619761],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e83685b1a25aac486353cdaea07288c7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e9df4da7d51b1bd115a632619ac95f02);
#
#
#             var marker_4f18238f2b0c1eecf8d2c9352ff182e1 = L.marker(
#                 [1.26547264, 103.821446],
#                 {}
#             ).addTo(map_e9df4da7d51b1bd115a632619ac95f02);
#
#
#             var icon_b7649a8cff71ff08af6bafcdb62e67fe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4f18238f2b0c1eecf8d2c9352ff182e1.setIcon(icon_b7649a8cff71ff08af6bafcdb62e67fe);
#
#
#         var popup_2ba7df7c0192bf42d58b8136da4dc4cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee3248eb05f8b7c71b4f6719d1c6458d = $(`&lt;div id=&quot;html_ee3248eb05f8b7c71b4f6719d1c6458d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NE1/CC29 Harbourfront&lt;/div&gt;`)[0];
#                 popup_2ba7df7c0192bf42d58b8136da4dc4cf.setContent(html_ee3248eb05f8b7c71b4f6719d1c6458d);
#
#
#
#         marker_4f18238f2b0c1eecf8d2c9352ff182e1.bindPopup(popup_2ba7df7c0192bf42d58b8136da4dc4cf)
#         ;
#
#
#
#
#             var marker_ee1b99faed834ef9c85b0ae2abff127c = L.marker(
#                 [1.331379525, 103.869046],
#                 {}
#             ).addTo(map_e9df4da7d51b1bd115a632619ac95f02);
#
#
#             var icon_18d8993c7fe422c4238e472738bedf72 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ee1b99faed834ef9c85b0ae2abff127c.setIcon(icon_18d8993c7fe422c4238e472738bedf72);
#
#
#         var popup_1cb4c3a90df1270cfe0078c9c5a0f00c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58571522a256f6dd62bedab0b61893d6 = $(`&lt;div id=&quot;html_58571522a256f6dd62bedab0b61893d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NE10 Potong Pasir&lt;/div&gt;`)[0];
#                 popup_1cb4c3a90df1270cfe0078c9c5a0f00c.setContent(html_58571522a256f6dd62bedab0b61893d6);
#
#
#
#         marker_ee1b99faed834ef9c85b0ae2abff127c.bindPopup(popup_1cb4c3a90df1270cfe0078c9c5a0f00c)
#         ;
#
#
#
#
#             var marker_a03c861b0cb92e8cb591f3561c91021b = L.marker(
#                 [1.339190046, 103.8708081],
#                 {}
#             ).addTo(map_e9df4da7d51b1bd115a632619ac95f02);
#
#
#             var icon_9f541a3927dfc32f8a08a7012e3e68f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a03c861b0cb92e8cb591f3561c91021b.setIcon(icon_9f541a3927dfc32f8a08a7012e3e68f5);
#
#
#         var popup_16db8fed7db8b1f4d05706b6551ce87e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6678c25148fe0159c993e46bca2867bf = $(`&lt;div id=&quot;html_6678c25148fe0159c993e46bca2867bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NE11 Woodleigh&lt;/div&gt;`)[0];
#                 popup_16db8fed7db8b1f4d05706b6551ce87e.setContent(html_6678c25148fe0159c993e46bca2867bf);
#
#
#
#         marker_a03c861b0cb92e8cb591f3561c91021b.bindPopup(popup_16db8fed7db8b1f4d05706b6551ce87e)
#         ;
#
#
#
#
#             var marker_e0d370be8a11797e8d1179cea0a342f6 = L.marker(
#                 [1.349707875, 103.8735637],
#                 {}
#             ).addTo(map_e9df4da7d51b1bd115a632619ac95f02);
#
#
#             var icon_751c833dbf70b7f1d21e4ebf7c34d9ac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;

# %% [markdown]
# We can see that the clustering algorithm strongly favours MRT/LRT stations that lies on the same MRT/LRT line, and also within the same region in Singapore.

# %% [markdown]
# ## Weekday PM Peak (5-7pm)

# %%
#Filter to show Weekday PM Peak (5-7pm)
weekday_pm_peak = df[(df['DAY_TYPE']=='WEEKDAY') & (df['TIME_PER_HOUR']<=19) & (df['TIME_PER_HOUR']>=17)].drop(columns=['DAY_TYPE'])
weekday_pm_peak=weekday_pm_peak.groupby(['ORIGIN_PT_CODE','DESTINATION_PT_CODE']).sum().reset_index().drop(columns=['TIME_PER_HOUR'])

# %%
# To transform and find out the total_trips per pair as a pct of trips by the sum of trips from each origin station
 
weekday_pm_peak.groupby('ORIGIN_PT_CODE')['TOTAL_TRIPS'].transform('sum')
weekday_pm_peak['sum_total_trips_origin']=weekday_pm_peak.groupby('ORIGIN_PT_CODE')['TOTAL_TRIPS'].transform('sum')
weekday_pm_peak['pct_trips_sum_origin']=weekday_pm_peak['TOTAL_TRIPS']/weekday_pm_peak['sum_total_trips_origin']

#Creating OD matrix with origins as rows and destinations as columns, values as the normalised trips by origin
od_weekdaypm_mat = weekday_pm_peak.pivot(index='ORIGIN_PT_CODE',columns='DESTINATION_PT_CODE',values='pct_trips_sum_origin').fillna(0)
od_weekdaypm_mat
# Out:
# DESTINATION_PT_CODE      BP10      BP11      BP12      BP13       BP2  \
# ORIGIN_PT_CODE
# BP10                 0.000000  0.047719  0.062879  0.051147  0.026364
# BP11                 0.037673  0.000000  0.027200  0.028509  0.035636
# BP12                 0.031290  0.019317  0.000000  0.028576  0.026341
# BP13                 0.083534  0.057993  0.029748  0.000000  0.043570
# BP2                  0.026615  0.027393  0.024903  0.018988  0.000000
# ...                       ...       ...       ...       ...       ...
# TE4                  0.000644  0.000322  0.000161  0.000000  0.002739
# TE5                  0.001775  0.000197  0.000197  0.000000  0.000592
# TE6                  0.000093  0.000186  0.000093  0.000000  0.000371
# TE7                  0.000659  0.000366  0.000220  0.000000  0.000512
# TE8                  0.000000  0.000054  0.000107  0.000000  0.001180
#
# DESTINATION_PT_CODE       BP3       BP4       BP5   BP6/DT1       BP7  ...  \
# ORIGIN_PT_CODE                                                         ...
# BP10                 0.034142  0.017137  0.031901  0.268521  0.052333  ...
# BP11                 0.028218  0.039127  0.048727  0.318545  0.021527  ...
# BP12                 0.036398  0.023308  0.033046  0.381386  0.018199  ...
# BP13                 0.037560  0.019531  0.022236  0.233173  0.006611  ...
# BP2                  0.040311  0.018833  0.032840  0.261323  0.012296  ...
# ...                       ...       ...       ...       ...       ...  ...
# TE4                  0.003867  0.001450  0.001208  0.002175  0.000000  ...
# TE5                  0.001183  0.000197  0.001775  0.002564  0.000000  ...
# TE6                  0.000928  0.000835  0.001485  0.004175  0.000000  ...
# TE7                  0.001610  0.000586  0.000000  0.007173  0.000000  ...
# TE8                  0.001180  0.000161  0.000000  0.013141  0.000000  ...
#
# DESTINATION_PT_CODE       SW6       SW7       SW8       TE1       TE3  \
# ORIGIN_PT_CODE
# BP10                 0.000000  0.000000  0.000000  0.000264  0.000264
# BP11                 0.000000  0.000000  0.000000  0.001018  0.000145
# BP12                 0.000000  0.000000  0.000000  0.000160  0.000479
# BP13                 0.000000  0.000000  0.000000  0.002103  0.000000
# BP2                  0.000000  0.000000  0.000000  0.001245  0.000934
# ...                       ...       ...       ...       ...       ...
# TE4                  0.000000  0.000081  0.000000  0.011278  0.074996
# TE5                  0.000000  0.000000  0.000000  0.007692  0.114201
# TE6                  0.000000  0.000000  0.000093  0.012247  0.086380
# TE7                  0.000586  0.000805  0.000000  0.003952  0.031618
# TE8                  0.000000  0.000000  0.000161  0.005793  0.048917
#
# DESTINATION_PT_CODE       TE4       TE5       TE6       TE7       TE8
# ORIGIN_PT_CODE
# BP10                 0.000000  0.000000  0.000264  0.000000  0.000000
# BP11                 0.000000  0.000000  0.000145  0.000000  0.000000
# BP12                 0.000160  0.000160  0.000958  0.000319  0.000000
# BP13                 0.000300  0.000000  0.000000  0.000000  0.000000
# BP2                  0.000156  0.000311  0.000156  0.000000  0.000467
# ...                       ...       ...       ...       ...       ...
# TE4                  0.000000  0.023925  0.045433  0.025858  0.037699
# TE5                  0.042801  0.000000  0.027219  0.032742  0.114004
# TE6                  0.030803  0.035071  0.000000  0.061514  0.131286
# TE7                  0.034473  0.037034  0.107297  0.000000  0.088121
# TE8                  0.028588  0.046181  0.126904  0.095259  0.000000
#
# [164 rows x 164 columns]

# %%
# hierarchical clustering and display dendogram

def plot_dendrogram(data: pd.DataFrame, **kwargs):
    clusters = shc.linkage(data,**kwargs)
    plt.figure(figsize=(25,16))
    plt.title("Hierarchical Clustering Dendrogram")
    shc.dendrogram(Z=clusters,leaf_font_size=8,labels=data.index)
    plt.axhline(y = 0.7, color = 'r', linestyle = '-')
    plt.show()

plot_dendrogram(od_weekdaypm_mat,method='ward',metric='euclidean')

# %% [markdown]
# Optimal cluster size is about 6

# %%
## get df of clusters results using cluster size found

def agg_cluster_fit(data: pd.DataFrame,cluster_size: int, **kwargs):
    model = AgglomerativeClustering(n_clusters=cluster_size,**kwargs) #affinity='euclidean', linkage='ward'
    model.fit(data)

    data['label'] = model.labels_

    d = [','.join(data[data['label']==x].index) for x in range(cluster_size)]
    df = pd.DataFrame(index=range(1,cluster_size+1),columns=['Stations'],data=d)

    return df


weekday_pm_peak_clusters = agg_cluster_fit(data=od_weekdaypm_mat,cluster_size=6,affinity='euclidean', linkage='ward')
weekday_pm_peak_clusters.style.set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_f59d6_row0_col0, #T_f59d6_row1_col0, #T_f59d6_row2_col0, #T_f59d6_row3_col0, #T_f59d6_row4_col0, #T_f59d6_row5_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_f59d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f59d6_level0_col0" class="col_heading level0 col0" >Stations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f59d6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f59d6_row0_col0" class="data row0 col0" >CC10/DT26,CC11,CC12,CC14,CC16,CC17/TE9,CC19/DT9,CC2,CC20,CC21,CC23,CC24,CC25,CC26,CC27,CC28,CC3,CC4/DT15,CC5,CC6,CC7,CC8,CE1/DT16,DT10,DT13,DT17,DT18,DT2,DT3,DT5,DT6,DT7,DT8,EW12/DT14,EW16/NE3,NE1/CC29,NE10,NE11,NE12/CC13,NE13,NE14,NE15,NE16/STC,NE17/PTC,NE4/DT19,NE5,NE7/DT12,NE8,NE9,NS24/NE6/CC1,PW3</td>
#     </tr>
#     <tr>
#       <th id="T_f59d6_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f59d6_row1_col0" class="data row1 col0" >CC22/EW21,EW11,EW13/NS25,EW14/NS26,EW15,EW17,EW18,EW19,EW20,EW22,EW23,EW24/NS1,EW25,EW26,EW27,EW28,EW29,EW30,EW31,EW32,EW33,NS10,NS11,NS12,NS13,NS14,NS15,NS16,NS17/CC15,NS18,NS19,NS2,NS20,NS21/DT11,NS22,NS23,NS27/CE2,NS28,NS3,NS4/BP1,NS5,NS7,NS8,NS9/TE2,TE1,TE3,TE4,TE5,TE6,TE7,TE8</td>
#     </tr>
#     <tr>
#       <th id="T_f59d6_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f59d6_row2_col0" class="data row2 col0" >CG1/DT35,CG2,DT20,DT21,DT22,DT23,DT24,DT25,DT27,DT28,DT29,DT30,DT31,DT33,DT34,EW1,EW10,EW2/DT32,EW3,EW4,EW5,EW6,EW7,EW8/CC9,EW9</td>
#     </tr>
#     <tr>
#       <th id="T_f59d6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f59d6_row3_col0" class="data row3 col0" >PE1,PE2,PE3,PE4,PE5,PE6,PE7,PW1,PW4,PW5,PW6,PW7</td>
#     </tr>
#     <tr>
#       <th id="T_f59d6_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f59d6_row4_col0" class="data row4 col0" >SE1,SE2,SE3,SE4,SE5,SW1,SW2,SW3,SW4,SW5,SW6,SW7,SW8</td>
#     </tr>
#     <tr>
#       <th id="T_f59d6_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_f59d6_row5_col0" class="data row5 col0" >BP10,BP11,BP12,BP13,BP2,BP3,BP4,BP5,BP6/DT1,BP7,BP8,BP9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Lets try to visualize the clusters on a map. Each cluster is set to a different colour so that we can identify the stations in a cluster easily.

# %%
# set a colour for each cluster

weekday_pm_peak_clusters['cluster_colour']=['red', 'blue', 'green', 'purple', 'orange', 'darkred']

#Define coordinates of where we want to center our map
sg = [1.3561519863229077, 103.80586415619761]

#Create the map
my_map = folium.Map(location = sg, zoom_start = 12)

#Load list of stations
mrt = pd.read_csv('mrt.csv')

#add markers
for i in range(len(weekday_pm_peak_clusters)):
    cluster_list = weekday_pm_peak_clusters.iloc[i].to_list()[0].split(',')
    colour = weekday_pm_peak_clusters.iloc[i].to_list()[1]
    add_markers(cluster_list,my_map,colour=colour)

# #Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_001fab56ee0e3a4443700a3773642674 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_001fab56ee0e3a4443700a3773642674&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_001fab56ee0e3a4443700a3773642674 = L.map(
#                 &quot;map_001fab56ee0e3a4443700a3773642674&quot;,
#                 {
#                     center: [1.3561519863229077, 103.80586415619761],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e04f7cf84313549eac5697a45442c0f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_001fab56ee0e3a4443700a3773642674);
#
#
#             var marker_76c146116366267ab424189f3fb1ee91 = L.marker(
#                 [1.326345372, 103.8902718],
#                 {}
#             ).addTo(map_001fab56ee0e3a4443700a3773642674);
#
#
#             var icon_2688fe3b7acd0d1a44bb0180afbd3003 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_76c146116366267ab424189f3fb1ee91.setIcon(icon_2688fe3b7acd0d1a44bb0180afbd3003);
#
#
#         var popup_c8c2c28846c198a49df2d22c166c7ee5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a6ae5183eab8df3c9499b21e58fc554 = $(`&lt;div id=&quot;html_3a6ae5183eab8df3c9499b21e58fc554&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CC10/DT26 Macpherson&lt;/div&gt;`)[0];
#                 popup_c8c2c28846c198a49df2d22c166c7ee5.setContent(html_3a6ae5183eab8df3c9499b21e58fc554);
#
#
#
#         marker_76c146116366267ab424189f3fb1ee91.bindPopup(popup_c8c2c28846c198a49df2d22c166c7ee5)
#         ;
#
#
#
#
#             var marker_5d17e515dcd7fd5fc18f6c7d0f300a9a = L.marker(
#                 [1.335433322, 103.88818],
#                 {}
#             ).addTo(map_001fab56ee0e3a4443700a3773642674);
#
#
#             var icon_36979553e13686ccfda9b1f45e7fbb3f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5d17e515dcd7fd5fc18f6c7d0f300a9a.setIcon(icon_36979553e13686ccfda9b1f45e7fbb3f);
#
#
#         var popup_de583ac9d2e5d69008b616104b507cdb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d8b84e6d91697ee6b63af8bf9637000 = $(`&lt;div id=&quot;html_6d8b84e6d91697ee6b63af8bf9637000&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CC11 Tai Seng&lt;/div&gt;`)[0];
#                 popup_de583ac9d2e5d69008b616104b507cdb.setContent(html_6d8b84e6d91697ee6b63af8bf9637000);
#
#
#
#         marker_5d17e515dcd7fd5fc18f6c7d0f300a9a.bindPopup(popup_de583ac9d2e5d69008b616104b507cdb)
#         ;
#
#
#
#
#             var marker_c2cce16a332b0310aa100b8d02d78271 = L.marker(
#                 [1.342828338, 103.8797462],
#                 {}
#             ).addTo(map_001fab56ee0e3a4443700a3773642674);
#
#
#             var icon_3d35eb74c072d8cc7a11ff4b34bf3aea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c2cce16a332b0310aa100b8d02d78271.setIcon(icon_3d35eb74c072d8cc7a11ff4b34bf3aea);
#
#
#         var popup_c9b4fbd4f5edddb89d7f99079b9e951c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa7f374011b2006fbe2e7502a1a5e4ec = $(`&lt;div id=&quot;html_fa7f374011b2006fbe2e7502a1a5e4ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CC12 Bartley&lt;/div&gt;`)[0];
#                 popup_c9b4fbd4f5edddb89d7f99079b9e951c.setContent(html_fa7f374011b2006fbe2e7502a1a5e4ec);
#
#
#
#         marker_c2cce16a332b0310aa100b8d02d78271.bindPopup(popup_c9b4fbd4f5edddb89d7f99079b9e951c)
#         ;
#
#
#
#
#             var marker_4bdb222bd17c87a4efa2f8b551e4d3a0 = L.marker(
#                 [1.351612171, 103.8641434],
#                 {}
#             ).addTo(map_001fab56ee0e3a4443700a3773642674);
#
#
#             var icon_510c4b211d84d13bec386686a6591d83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quo

# %% [markdown]
# ## Weekends Noon (11-1pm)

# %%
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering

# %%
#Filter to show Weekend Noon Peak (11-1am)
weekend_peak = df[(df['DAY_TYPE']=='WEEKDAY') & (df['TIME_PER_HOUR']<=13) & (df['TIME_PER_HOUR']>=11)].drop(columns=['DAY_TYPE'])
weekend_peak=weekend_peak.groupby(['ORIGIN_PT_CODE','DESTINATION_PT_CODE']).sum().reset_index().drop(columns=['TIME_PER_HOUR'])

# %%
# To transform and find out the total_trips per pair as a pct of trips by the sum of trips from each origin station
 
weekend_peak.groupby('ORIGIN_PT_CODE')['TOTAL_TRIPS'].transform('sum')
weekend_peak['sum_total_trips_origin']=weekend_peak.groupby('ORIGIN_PT_CODE')['TOTAL_TRIPS'].transform('sum')
weekend_peak['pct_trips_sum_origin']=weekend_peak['TOTAL_TRIPS']/weekend_peak['sum_total_trips_origin']

#Creating OD matrix with origins as rows and destinations as columns, values as the normalised trips by origin
od_weekend_mat = weekend_peak.pivot(index='ORIGIN_PT_CODE',columns='DESTINATION_PT_CODE',values='pct_trips_sum_origin').fillna(0)
od_weekend_mat
# Out:
# DESTINATION_PT_CODE      BP10      BP11      BP12      BP13       BP2  \
# ORIGIN_PT_CODE
# BP10                 0.000000  0.053183  0.063512  0.042993  0.017588
# BP11                 0.001004  0.000000  0.018936  0.029981  0.022809
# BP12                 0.010195  0.000703  0.000000  0.044176  0.028123
# BP13                 0.007932  0.004271  0.000305  0.000000  0.028981
# BP2                  0.021167  0.016517  0.004490  0.004811  0.000000
# ...                       ...       ...       ...       ...       ...
# TE4                  0.000238  0.000475  0.000000  0.000000  0.000475
# TE5                  0.000000  0.000000  0.000000  0.000000  0.000000
# TE6                  0.000000  0.000000  0.000173  0.000086  0.000000
# TE7                  0.000000  0.000000  0.000000  0.000000  0.000000
# TE8                  0.000000  0.000000  0.000128  0.000000  0.000000
#
# DESTINATION_PT_CODE       BP3       BP4       BP5   BP6/DT1       BP7  ...  \
# ORIGIN_PT_CODE                                                         ...
# BP10                 0.040620  0.031407  0.045505  0.380793  0.020519  ...
# BP11                 0.040597  0.037441  0.044326  0.386028  0.003730  ...
# BP12                 0.033161  0.029880  0.035036  0.488985  0.017928  ...
# BP13                 0.067114  0.061318  0.021660  0.324283  0.009457  ...
# BP2                  0.044419  0.023573  0.024375  0.314144  0.015555  ...
# ...                       ...       ...       ...       ...       ...  ...
# TE4                  0.000713  0.001900  0.000000  0.001663  0.000000  ...
# TE5                  0.000759  0.004556  0.000000  0.000759  0.000000  ...
# TE6                  0.000778  0.003198  0.000000  0.002938  0.000086  ...
# TE7                  0.000750  0.001124  0.000000  0.004497  0.000250  ...
# TE8                  0.000255  0.000000  0.000000  0.006384  0.000000  ...
#
# DESTINATION_PT_CODE       SW6       SW7      SW8       TE1       TE3  \
# ORIGIN_PT_CODE
# BP10                 0.000000  0.000000  0.00000  0.000140  0.000419
# BP11                 0.000000  0.000000  0.00000  0.000430  0.000287
# BP12                 0.000000  0.000000  0.00000  0.001406  0.000117
# BP13                 0.000000  0.000000  0.00000  0.001220  0.000305
# BP2                  0.000000  0.000000  0.00016  0.001443  0.000481
# ...                       ...       ...      ...       ...       ...
# TE4                  0.000000  0.000238  0.00000  0.020190  0.079335
# TE5                  0.000000  0.000000  0.00000  0.020121  0.040243
# TE6                  0.000086  0.000000  0.00000  0.015124  0.033273
# TE7                  0.000250  0.000125  0.00000  0.003623  0.026608
# TE8                  0.000128  0.000128  0.00000  0.008427  0.028218
#
# DESTINATION_PT_CODE       TE4       TE5       TE6       TE7       TE8
# ORIGIN_PT_CODE
# BP10                 0.000000  0.000000  0.000000  0.000279  0.000000
# BP11                 0.000000  0.000000  0.000143  0.000000  0.000143
# BP12                 0.000000  0.000000  0.000703  0.000000  0.000117
# BP13                 0.000000  0.000000  0.000000  0.000000  0.000000
# BP2                  0.000000  0.000000  0.000160  0.000000  0.000481
# ...                       ...       ...       ...       ...       ...
# TE4                  0.000000  0.046793  0.062470  0.057957  0.087173
# TE5                  0.061503  0.000000  0.050114  0.064920  0.211086
# TE6                  0.029384  0.043039  0.000000  0.117103  0.133005
# TE7                  0.048595  0.060837  0.186633  0.000000  0.160400
# TE8                  0.032942  0.060904  0.114785  0.145940  0.000000
#
# [164 rows x 164 columns]

# %%
# hierarchical clustering and display dendogram

def plot_dendrogram(data: pd.DataFrame, **kwargs):
    clusters = shc.linkage(data,**kwargs)
    plt.figure(figsize=(25,16))
    plt.title("Hierarchical Clustering Dendrogram")
    shc.dendrogram(Z=clusters,leaf_font_size=8,labels=data.index)
    plt.axhline(y = 0.82, color = 'r', linestyle = '-')
    plt.show()

plot_dendrogram(od_weekend_mat,method='ward',metric='euclidean')

# %% [markdown]
# Optimal cluster size is about 7

# %%
## get df of clusters results using cluster size found

def agg_cluster_fit(data: pd.DataFrame,cluster_size: int, **kwargs):
    model = AgglomerativeClustering(n_clusters=cluster_size,**kwargs) #affinity='euclidean', linkage='ward'
    model.fit(data)

    data['label'] = model.labels_

    d = [','.join(data[data['label']==x].index) for x in range(cluster_size)]
    df = pd.DataFrame(index=range(1,cluster_size+1),columns=['Stations'],data=d)

    return df


weekend_peak_clusters = agg_cluster_fit(data=od_weekend_mat,cluster_size=7,affinity='euclidean', linkage='ward')
weekend_peak_clusters.style.set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_05df6_row0_col0, #T_05df6_row1_col0, #T_05df6_row2_col0, #T_05df6_row3_col0, #T_05df6_row4_col0, #T_05df6_row5_col0, #T_05df6_row6_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_05df6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05df6_level0_col0" class="col_heading level0 col0" >Stations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05df6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_05df6_row0_col0" class="data row0 col0" >BP6/DT1,CC10/DT26,CC11,CC12,CC14,CC16,CC17/TE9,CC19/DT9,CC2,CC20,CC21,CC22/EW21,CC23,CC24,CC25,CC26,CC27,CC28,CC3,CC4/DT15,CC5,CC6,CC7,CC8,CG2,DT10,DT13,DT3,DT5,DT6,DT7,DT8,EW10,EW11,EW12/DT14,EW13/NS25,EW14/NS26,EW15,EW16/NE3,EW2/DT32,EW4,EW5,EW6,EW7,EW8/CC9,EW9,NE1/CC29,NE10,NE11,NE12/CC13,NE13,NE14,NE15,NE16/STC,NE17/PTC,NE4/DT19,NE5,NE7/DT12,NE8,NE9,NS10,NS11,NS12,NS13,NS14,NS15,NS16,NS17/CC15,NS18,NS19,NS20,NS21/DT11,NS22,NS23,NS24/NE6/CC1,NS27/CE2,NS28,NS7,NS8,NS9/TE2</td>
#     </tr>
#     <tr>
#       <th id="T_05df6_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_05df6_row1_col0" class="data row1 col0" >BP10,BP11,BP12,BP13,BP2,BP3,BP4,BP5,BP7,BP8,BP9,DT2</td>
#     </tr>
#     <tr>
#       <th id="T_05df6_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_05df6_row2_col0" class="data row2 col0" >CE1/DT16,CG1/DT35,DT17,DT18,DT20,DT21,DT22,DT23,DT24,DT25,DT27,DT28,DT29,DT30,DT31,DT33,DT34,EW1,EW3</td>
#     </tr>
#     <tr>
#       <th id="T_05df6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_05df6_row3_col0" class="data row3 col0" >SE1,SE2,SE3,SE4,SE5,SW1,SW2,SW3,SW4,SW5,SW6,SW7,SW8</td>
#     </tr>
#     <tr>
#       <th id="T_05df6_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_05df6_row4_col0" class="data row4 col0" >TE1,TE3,TE4,TE5,TE6,TE7,TE8</td>
#     </tr>
#     <tr>
#       <th id="T_05df6_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_05df6_row5_col0" class="data row5 col0" >PE1,PE2,PE3,PE4,PE5,PE6,PE7,PW1,PW3,PW4,PW5,PW6,PW7</td>
#     </tr>
#     <tr>
#       <th id="T_05df6_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_05df6_row6_col0" class="data row6 col0" >EW17,EW18,EW19,EW20,EW22,EW23,EW24/NS1,EW25,EW26,EW27,EW28,EW29,EW30,EW31,EW32,EW33,NS2,NS3,NS4/BP1,NS5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Lets try to visualize the clusters on a map. Each cluster is set to a different colour so that we can identify the stations in a cluster easily.

# %%
# set a colour for each cluster

weekend_peak_clusters['cluster_colour']=['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred']

#Define coordinates of where we want to center our map
sg = [1.3561519863229077, 103.80586415619761]

#Create the map
my_map = folium.Map(location = sg, zoom_start = 12)

#Load list of stations
mrt = pd.read_csv('mrt.csv')

#add markers
for i in range(len(weekend_peak_clusters)):
    cluster_list = weekend_peak_clusters.iloc[i].to_list()[0].split(',')
    colour = weekend_peak_clusters.iloc[i].to_list()[1]
    add_markers(cluster_list,my_map,colour=colour)

# #Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0fe89f38f13783691278b53056ad05c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0fe89f38f13783691278b53056ad05c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c0fe89f38f13783691278b53056ad05c = L.map(
#                 &quot;map_c0fe89f38f13783691278b53056ad05c&quot;,
#                 {
#                     center: [1.3561519863229077, 103.80586415619761],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e2da14698ae4ced2090bd5ab36a170b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c0fe89f38f13783691278b53056ad05c);
#
#
#             var marker_2e17620ff7f7c2d6624e6291a81ba2af = L.marker(
#                 [1.379002117, 103.7615559],
#                 {}
#             ).addTo(map_c0fe89f38f13783691278b53056ad05c);
#
#
#             var icon_7444e1c45cfd16056ecd251c26bdd461 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2e17620ff7f7c2d6624e6291a81ba2af.setIcon(icon_7444e1c45cfd16056ecd251c26bdd461);
#
#
#         var popup_f88176fc8bf108b157b18ad23f6ff87d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1886eb2c524a9c427bac4c2f9fffb360 = $(`&lt;div id=&quot;html_1886eb2c524a9c427bac4c2f9fffb360&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BP6/DT1 Bukit Panjang&lt;/div&gt;`)[0];
#                 popup_f88176fc8bf108b157b18ad23f6ff87d.setContent(html_1886eb2c524a9c427bac4c2f9fffb360);
#
#
#
#         marker_2e17620ff7f7c2d6624e6291a81ba2af.bindPopup(popup_f88176fc8bf108b157b18ad23f6ff87d)
#         ;
#
#
#
#
#             var marker_faa8ecf3e5d976f8543986cd3fbc719a = L.marker(
#                 [1.326345372, 103.8902718],
#                 {}
#             ).addTo(map_c0fe89f38f13783691278b53056ad05c);
#
#
#             var icon_dc5b87b75eb9c9f0b97235a2ab0bd0cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_faa8ecf3e5d976f8543986cd3fbc719a.setIcon(icon_dc5b87b75eb9c9f0b97235a2ab0bd0cb);
#
#
#         var popup_295a1a4cc1fddcbb0ed6d7bb03f3b389 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c09747499f7e57754dd47ec8b2ce04f3 = $(`&lt;div id=&quot;html_c09747499f7e57754dd47ec8b2ce04f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CC10/DT26 Macpherson&lt;/div&gt;`)[0];
#                 popup_295a1a4cc1fddcbb0ed6d7bb03f3b389.setContent(html_c09747499f7e57754dd47ec8b2ce04f3);
#
#
#
#         marker_faa8ecf3e5d976f8543986cd3fbc719a.bindPopup(popup_295a1a4cc1fddcbb0ed6d7bb03f3b389)
#         ;
#
#
#
#
#             var marker_bdad44c4c7a88745c3645f54b6022334 = L.marker(
#                 [1.335433322, 103.88818],
#                 {}
#             ).addTo(map_c0fe89f38f13783691278b53056ad05c);
#
#
#             var icon_358e206bc06c99f68e6adf72adc72eac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bdad44c4c7a88745c3645f54b6022334.setIcon(icon_358e206bc06c99f68e6adf72adc72eac);
#
#
#         var popup_ba73f8ebccdee7b7236124841b9c6314 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1adecc6c14bc2d594bbee83939e9d769 = $(`&lt;div id=&quot;html_1adecc6c14bc2d594bbee83939e9d769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CC11 Tai Seng&lt;/div&gt;`)[0];
#                 popup_ba73f8ebccdee7b7236124841b9c6314.setContent(html_1adecc6c14bc2d594bbee83939e9d769);
#
#
#
#         marker_bdad44c4c7a88745c3645f54b6022334.bindPopup(popup_ba73f8ebccdee7b7236124841b9c6314)
#         ;
#
#
#
#
#             var marker_d8ff1abb3d3046291946be24538749e1 = L.marker(
#                 [1.342828338, 103.8797462],
#                 {}
#             ).addTo(map_c0fe89f38f13783691278b53056ad05c);
#
#
#             var icon_1d8dbe5d145f5a05d0f29c2b159ef072 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&qu

# %% [markdown]
# ## Closing Thoughts
